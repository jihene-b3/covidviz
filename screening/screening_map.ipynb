# %%
import pandas as pd
import numpy as np
import folium
from folium import IFrame
import folium.plugins

# %%
grand_public_path = '../covidviz/data/scr_public_centers.csv'
depis_grand_public = pd.read_csv(grand_public_path)

# all informtations about screening centers in restricted access in France
acces_restreint_path = '../covidviz/data/scr_private_centers.csv'
depis_acces_restreint = pd.read_csv(acces_restreint_path)

# %%
depis_grand_public.drop(['ID', 'finess', 'date_modif'],1, inplace=True)
depis_acces_restreint.drop(['ID', 'finess', 'date_modif'],1, inplace=True)

# %%
depis_grand_public[depis_grand_public['latitude'].isnull() == True]
# Out:
#           id_ej                                         rs  \
# 1269  500020979                          cabinet infirmier
# 1828  630010916                          LBM GEN BIO VICHY
# 2388  750049371           Parking Chennevière Place Tukums
# 2595  780020855  Centre Covid Biosynergie Les Ulis Loxamed
# 2742  830018644                                        NaN
# 2844  860012756                          Cabinet infirmier
# 3093  920034204                     BIOETHERNALYS ASNIERES
#
#                            adresse  \
# 1269                           NaN
# 1828  75 ALL DES AILES 03200 VICHY
# 2388                           NaN
# 2595                           NaN
# 2742                           NaN
# 2844                           NaN
# 3093                           NaN
#
#                                                 cpl_loc do_prel do_antigenic  \
# 1269                                  Cabinet infirmier     OUI          NON
# 1828                                                NaN     OUI          NON
# 2388                                              DRIVE     OUI          OUI
# 2595  Piscine des Ulis, Avenue de l'Aubrac, 91940 Le...     OUI          NON
# 2742                                                NaN     OUI          NON
# 2844  Tivoli sur le parking du marché, centre du bou...     OUI          NON
# 3093                                                NaN     OUI          NON
#
#       longitude  latitude   mod_prel                       public  \
# 1269        NaN       NaN  Sur place                  Tout public
# 1828        NaN       NaN  Sur place                  Tout public
# 2388        NaN       NaN  Sur place  Tout public/Enfants 0-3 ans
# 2595        NaN       NaN  Sur place                  Tout public
# 2742        NaN       NaN  Sur place                  Tout public
# 2844        NaN       NaN  Sur place                  Tout public
# 3093        NaN       NaN  Sur place                  Tout public
#
#                                                 horaire horaire_prio  \
# 1269                                                NaN          NaN
# 1828  lundi : 9h15 -17h45 | mardi : 9h15 -17h45 | me...          NaN
# 2388  lundi : 9h30-12h | mardi :  9h30-12h | mercred...          NaN
# 2595  Du lundi au samedi 9h - 13h / 14h - 17h  |    ...          NaN
# 2742                                                NaN          NaN
# 2844  Horaires variables en fonction des disponibili...          NaN
# 3093                                                NaN          NaN
#
#                        check_rdv  \
# 1269  Sur rendez-vous uniquement
# 1828  Sur rendez-vous uniquement
# 2388  Sur rendez-vous uniquement
# 2595    Avec ou sans rendez-vous
# 2742                         NaN
# 2844  Sur rendez-vous uniquement
# 3093                         NaN
#
#                                                 tel_rdv        web_rdv
# 1269                                         0750060015            NaN
# 1828                                         0626448655  www.genbio.fr
# 2388                                         0145760425            TEL
# 2595  Hotline PCR : infocovid.idf@biogroup.fr ou 017...            NaN
# 2742                                                NaN            NaN
# 2844                                     05.49.51.62.85            NaN
# 3093                                                NaN            NaN

# %%
depis_grand_public.drop([2388,2742],inplace=True)

depis_grand_public.loc[1269,'adresse'] = '6 Rue St Hermeland 50260 SOTTEVAST'
depis_grand_public.loc[1269,'longitude'] = -1.5945067
depis_grand_public.loc[1269,'latitude'] = 49.5224947

depis_grand_public.loc[1828,'longitude'] = 3.409963
depis_grand_public.loc[1828,'latitude'] = 46.1502923

depis_grand_public.loc[2595,'longitude'] = 2.1660581
depis_grand_public.loc[2595,'latitude'] = 48.6789083

depis_grand_public.loc[2595,'adresse'] = depis_grand_public.loc[2595,'cpl_loc']
depis_grand_public.loc[2595,'cpl_loc'] = np.nan

depis_grand_public.loc[2844,'longitude'] = 0.16686641335383762
depis_grand_public.loc[2844,'latitude'] = 46.63853367849356

depis_grand_public.loc[3093,'adresse'] = '286 Av. des Grésillons, 92600 Asnières-sur-Seine'
depis_grand_public.loc[3093,'tel_rdv'] = '01 85 78 53 43'
depis_grand_public.loc[3093,'longitude'] = 2.3141661
depis_grand_public.loc[3093,'latitude'] = 48.9202844

# %%
depis_grand_public = depis_grand_public.reset_index()

# %%
for row in range(len(depis_grand_public)) :
    depis_grand_public.loc[row,'dep'] = depis_grand_public.loc[row,'id_ej'][:2]

# %%
for row in range(len(depis_acces_restreint)) :
    depis_acces_restreint.loc[row,'dep'] = str(depis_acces_restreint.loc[row,'id_ej'])[:2]

# %%
depis_grand_public.head()
# Out:
#    index      id_ej                               rs  \
# 0      0  010001725     LBM CROIX BLANCHE BOURG EN B
# 1      1  010009843  LBM BIOPTEAM BOURG EN B LALANDE
# 2      2  010009843   LBM BIOPTEAM BOURG EN B BRETIN
# 3      3  010009843              LBM BIOPTEAM VONNAS
# 4      4  020000063                 CH SAINT-QUENTIN
#
#                                            adresse cpl_loc do_prel  \
# 0       51 AV AMEDEE MERCIER 01000 BOURG EN BRESSE     NaN     OUI
# 1    14 R DE LA GRENOUILLERE 01000 BOURG EN BRESSE     NaN     OUI
# 2               8 PL JOUBERT 01000 BOURG EN BRESSE     NaN     OUI
# 3            48 PL FERDINAND DE BEOST 01540 VONNAS     NaN     OUI
# 4  1 R MICHEL DE L'HOSPITAL 02321 ST QUENTIN CEDEX     NaN     OUI
#
#   do_antigenic  longitude   latitude   mod_prel       public  \
# 0          NON   5.241852  46.203851  Sur place  Tout public
# 1          NON   5.226313  46.208489  Sur place  Tout public
# 2          NON   5.222134  46.203186  Sur place  Tout public
# 3          NON   4.991750  46.218786  Sur place  Tout public
# 4          NON   3.269153  49.861845  Sur place  Tout public
#
#                                              horaire horaire_prio  \
# 0  lundi : 8h00-12h00 et 14h00-19h00 | mardi : 8h...          NaN
# 1                                                NaN          NaN
# 2  lundi : 10h00-12h00  mardi : 10h00-12h00  merc...          NaN
# 3  lundi : 8h30-16h30  mardi : 8h30-16h30  mercre...          NaN
# 4                                                NaN          NaN
#
#                     check_rdv     tel_rdv web_rdv dep
# 0  Sur rendez-vous uniquement  0474452636     NaN  01
# 1                         NaN  0474226107     NaN  01
# 2                         NaN  0474225209     NaN  01
# 3                         NaN  0474500517     NaN  01
# 4                         NaN         NaN     NaN  02

# %%
depis_acces_restreint[depis_acces_restreint['latitude'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [id_ej, rs, adresse, cpl_loc, do_prel, do_antigenic, longitude, latitude, mod_prel, public, horaire, horaire_prio, check_rdv, tel_rdv, web_rdv, dep]
# Index: []

# %%
depis_acces_restreint.head()
# Out:
#        id_ej                                        rs  \
# 0   10008407            CH DU HAUT BUGEY - GEOVREISSET
# 1   60021904  LBM EUROFINS LABAZUR NICE SITE ST GEORGE
# 2  120006309                           CSI UDSMA RODEZ
# 3  120006309                   CSI UDSMA MUR DE BARREZ
# 4  120006309        CSI UDSMA VILLEFRANCHE DE ROUERGUE
#
#                                             adresse  \
# 0              1 RTE DE VEYZIAT 01108 OYONNAX CEDEX
# 1                         2 AV DE RIMIEZ 06000 NICE
# 2               31 Avenue de la Gineste 12000 Rodez
# 3    Avenue du Cardinal Verdier 12600 Mur-de-Barrez
# 4  12 Quai du Temple 12200 Villefranche-de-Rouergue
#
#                                              cpl_loc do_prel do_antigenic  \
# 0                                                NaN     OUI          NON
# 1                                                NaN     OUI          NON
# 2  LABORATOIRE DE SECTEUR LxBIO Béteille - 22 rue...     OUI          NON
# 3  LABORATOIRE DE SECTEUR LxBIO ESPALION - 4 av d...     OUI          NON
# 4  LABORATOIRE DE SECTEUR LxBIO VILLEFRANCHE DE R...     OUI          NON
#
#    longitude   latitude         mod_prel  \
# 0   5.627348  46.275059        Sur place
# 1   7.272878  43.739412   En étab. santé
# 2   2.566289  44.361668  Equipes mobiles
# 3   2.660854  44.843268  Equipes mobiles
# 4   2.039347  44.349350  Equipes mobiles
#
#                                               public               horaire  \
# 0  Personnel soignant/patients hospitalisés dans ...                   NaN
# 1                                       Hospitalisés  Non ouvert au public
# 2                                  patients fragiles                   NaN
# 3                                  patients fragiles                   NaN
# 4                                  patients fragiles                   NaN
#
#   horaire_prio                   check_rdv  \
# 0          NaN                         NaN
# 1          NaN  Sur rendez-vous uniquement
# 2          NaN  Sur rendez-vous uniquement
# 3          NaN  Sur rendez-vous uniquement
# 4          NaN  Sur rendez-vous uniquement
#
#                                      tel_rdv web_rdv dep
# 0                                 0474731002     NaN  10
# 1                                        NaN     NaN  60
# 2  06 80 39 53 66 (à partir du lundi 18 mai)     NaN  12
# 3  06 80 39 53 66 (à partir du lundi 18 mai)     NaN  12
# 4  06 80 39 53 66 (à partir du lundi 18 mai)     NaN  12

# %%
dep_fr = pd.read_csv('../screening/data/depart_fr_coord.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-be84b65bd372> in <module>
# ----> 1 dep_fr = pd.read_csv('../screening/data/depart_fr_coord.csv', delimiter=';')
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/opt/anaconda3/envs/stef_env/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../screening/data/depart_fr_coord.csv'

# %%
dep_fr.head()
# Out:
#   maille_code               maille_nom   Latitude  Longitude  Unnamed: 4  \
# 0          01                      Ain  46.064468   4.903189         NaN
# 1          02                    Aisne  49.447935   2.485857         NaN
# 2          03                   Allier  46.366144   2.580819         NaN
# 3          04  Alpes-de-Haute-Provence  44.162792   5.672461         NaN
# 4          05             Hautes-Alpes  44.655276   5.687306         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
dep_fr.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'], 1, inplace=True)

# %%
def map_dep(department) :
    return(folium.Map(location=[dep_fr[dep_fr['maille_code']==f'{department}']['Latitude'],dep_fr[dep_fr['maille_code']==f'{department}']['Longitude']], zoom_start=8))

# %%
all_map_dep = {}

for dep_code in dep_fr['maille_code'].tolist() :
    all_map_dep[f'{dep_code}'] = map_dep(f'{dep_code}')

# %%
depis_department_grand_public = {}
for dep_code in dep_fr['maille_code'].tolist() :
    depis_department_grand_public[f'{dep_code}'] = depis_grand_public[depis_grand_public['dep']==f'{dep_code}']
    depis_department_grand_public[f'{dep_code}'] = depis_department_grand_public[f'{dep_code}'].reset_index()
    depis_department_grand_public[f'{dep_code}'].drop(['level_0', 'index'], 1, inplace=True)

# %%
depis_department_acces_restreint = {}
for dep_code in dep_fr['maille_code'].tolist() :
    depis_department_acces_restreint[f'{dep_code}'] = depis_acces_restreint[depis_acces_restreint['dep']==f'{dep_code}']
    depis_department_acces_restreint[f'{dep_code}'] = depis_department_acces_restreint[f'{dep_code}'].reset_index()
    depis_department_acces_restreint[f'{dep_code}'].drop(['index'], 1, inplace=True)

# %%
dep_acces_restreint_list = []
for dep_code in dep_fr['maille_code'].tolist():
    if (len(depis_department_acces_restreint[f'{dep_code}']) != 0) :
        a = f'{dep_code}'
        dep_acces_restreint_list.append(a)
    else : del depis_department_acces_restreint[f'{dep_code}']

# %%
for dep_code in dep_fr['maille_code'].tolist() :
    depis_department_grand_public[f'{dep_code}'].fillna('-', inplace=True)

# %%
for dep_code in dep_acces_restreint_list :
    depis_department_acces_restreint[f'{dep_code}'].fillna('-', inplace=True)

# %%
type(depis_department_grand_public['34'].loc[0,'web_rdv'])
# Out:
# str

# %%
depis_department_acces_restreint['34'].head(4)
# Out:
#        id_ej                               rs  \
# 0  340019306  LBM LABOSUD MONTPELLIER GAROSUD
# 1  340019306         LBM LABOSUD LUNEL VAUBAN
# 2  340019306              LBM LABOSUD BÉZIERS
# 3  340019306                 LBM LABOSUD ALÈS
#
#                                        adresse                    cpl_loc  \
# 0  90 Rue Nicolas Chédeville 34070 Montpellier  Centre de dépistage dédié
# 1  207 Avenue du General de Gaulle 34400 Lunel  Centre de dépistage dédié
# 2          Avenue des Olympiades 34500 Béziers  Centre de dépistage dédié
# 3          40 Avenue Vincent d'Indy 30100 Alès  Centre de dépistage dédié
#
#   do_prel do_antigenic  longitude   latitude mod_prel  \
# 0     OUI          NON   3.863864  43.573135    Drive
# 1     OUI          NON   4.140210  43.676807    Drive
# 2     OUI          NON   3.264036  43.335929    Drive
# 3     OUI          NON   4.101607  44.135701    Drive
#
#                                               public horaire horaire_prio  \
# 0  Patients avec symptômes/Cas contacts liste CPA...       -            -
# 1  Cas contacts liste CPAM/Personnel soignant/Pat...       -            -
# 2  Cas contacts liste CPAM/Personnel soignant/Pat...       -            -
# 3  Cas contacts liste CPAM/Personnel soignant/Pat...       -            -
#
#                     check_rdv tel_rdv                        web_rdv dep
# 0  Sur rendez-vous uniquement       -  https://labosud.fr/rdvcovid19  34
# 1  Sur rendez-vous uniquement       -  https://labosud.fr/rdvcovid19  34
# 2            Sans rendez-vous       -                              -  34
# 3  Sur rendez-vous uniquement       -  https://labosud.fr/rdvcovid19  34

# %%
for dep_code in dep_fr['maille_code'].tolist():
    for i in range(len(depis_department_grand_public[f'{dep_code}'])):

        tooltip = f"<strong>{depis_department_grand_public[dep_code].loc[i,'adresse']}</strong>"

        popup = folium.Popup(
          '<h4><b><p style="text-align:center;">{}</p></b></h4><br>'.format(depis_department_grand_public[dep_code].loc[i,'rs'])+
            '<h5><b>Adresse : </b></h5>{}'.format(depis_department_grand_public[dep_code].loc[i,'adresse']) + 
            '<br>' +
            '<i>{}</i>'.format(depis_department_grand_public[dep_code].loc[i,'cpl_loc']) +
            '<br>' +
            '<strong><b>Test RT-PCR : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'do_prel']) +
            '<br>' +
            '<strong><b>Test antigénique : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'do_antigenic'])+
            '<br>' +
            '<strong><b>Modalités de prélèvement : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,       'mod_prel']) +
            '<br>' +
            '<strong><b>Public : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'public']) +
            '<br>' +
            '<strong><b>Accès : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'check_rdv']) +
            '<br>' +
            '<h5><b>Horaire : </b></h5>{}'.format(depis_department_grand_public[dep_code].loc[i,'horaire']) +
            '<br>' +
            '<strong><b>Horaire personnes prioritaires : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'horaire_prio']) +
            '<br>' +
            '<strong><b>Téléphone : </b></strong>{}'.format(str(depis_department_grand_public[dep_code].loc[i,'tel_rdv'])) +
            '<br>' +
            '<strong><b>Site internet : </b></strong>{}'.format(depis_department_grand_public[dep_code].loc[i,'web_rdv']),
            max_width=500)

        icon = icon=folium.Icon(color='green')

        folium.Marker(location=[depis_department_grand_public[f'{dep_code}'].loc[i,'latitude'], 
            depis_department_grand_public[f'{dep_code}'].loc[i,'longitude']], 
            icon=icon, popup=popup, tooltip=tooltip).add_to(all_map_dep[f'{dep_code}'])

# %%
for dep_code in dep_acces_restreint_list :
    for i in range(len(depis_department_acces_restreint[f'{dep_code}'])):

        tooltip = f"<strong>{depis_department_acces_restreint[dep_code].loc[i,'adresse']}</strong>"

        popup = folium.Popup(
          '<h4><b><p style="text-align:center;">{}</p></b></h4><br>'.format(depis_department_acces_restreint[dep_code].loc[i,'rs'])+
            '<h5><b>Adresse : </b></h5>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'adresse']) + 
            '<br>' +
            '<i>{}</i>'.format(depis_department_acces_restreint[dep_code].loc[i,'cpl_loc']) +
            '<br>' +
            '<strong><b>Test RT-PCR : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'do_prel']) +
            '<br>' +
            '<strong><b>Test antigénique : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'do_antigenic'])+
            '<br>' +
            '<strong><b>Modalités de prélèvement : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,       'mod_prel']) +
            '<br>' +
            '<strong><b>Public : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'public']) +
            '<br>' +
            '<strong><b>Accès : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'check_rdv']) +
            '<br>' +
            '<h5><b>Horaire : </b></h5>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'horaire']) +
            '<br>' +
            '<strong><b>Horaire personnes prioritaires : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'horaire_prio']) +
            '<br>' +
            '<strong><b>Téléphone : </b></strong>{}'.format(str(depis_department_acces_restreint[dep_code].loc[i,'tel_rdv'])) +
            '<br>' +
            '<strong><b>Site internet : </b></strong>{}'.format(depis_department_acces_restreint[dep_code].loc[i,'web_rdv']),
            max_width=500)

        icon = folium.Icon(color='red')

        folium.Marker(
            location=[depis_department_acces_restreint[f'{dep_code}'].loc[i,'latitude'], 
            depis_department_acces_restreint[f'{dep_code}'].loc[i,'longitude']], 
            icon=icon, popup=popup, tooltip=tooltip).add_to(all_map_dep[f'{dep_code}'])

# %%
all_map_dep['34']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_011709237b9147e69791d932aefe5b44%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_011709237b9147e69791d932aefe5b44%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_011709237b9147e69791d932aefe5b44%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_011709237b9147e69791d932aefe5b44%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.590116%2C%202.8065874%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
def map_screening(dep_code):
    return(all_map_dep[f'{dep_code}'])

# %%
map_screening('34')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_011709237b9147e69791d932aefe5b44%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_011709237b9147e69791d932aefe5b44%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_011709237b9147e69791d932aefe5b44%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_011709237b9147e69791d932aefe5b44%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.590116%2C%202.8065874%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
type(map_dep('34'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-436bbfb09df8> in <module>
# ----> 1 type(map_dep('34'))
#
# NameError: name 'map_dep' is not defined
