# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from download import download

# %%
url1 ='https://www.data.gouv.fr/fr/datasets/r/0b66ca39-1623-4d9c-83ad-5434b7f9e2a4'
path_target = "./covid.csv"
download(url1, path_target, replace=True)
df_covid = pd.read_csv("covid.csv")
df_covid.head(n=100)
print(df_covid)
# Out:
# Downloading data from https://raw.githubusercontent.com/opencovid19-fr/data/master/dist/chiffres-cles.csv (5.9 MB)
#
# file_sizes: 100%|██████████████████████████| 6.24M/6.24M [00:00<00:00, 6.83MB/s]
# Successfully downloaded file to ./covid.csv
# C:\Users\zakaria\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              date granularite maille_code                  maille_nom  \
# 0      2020-01-01        pays         FRA                      France
# 1      2020-01-07        pays         FRA                      France
# 2      2020-01-08        pays         FRA                      France
# 3      2020-01-16        pays         FRA                      France
# 4      2020-01-17        pays         FRA                      France
# ...           ...         ...         ...                         ...
# 47169  2021-03-16      region      REG-75          Nouvelle-Aquitaine
# 47170  2021-03-16      region      REG-76                   Occitanie
# 47171  2021-03-16      region      REG-84        Auvergne-Rhône-Alpes
# 47172  2021-03-16      region      REG-93  Provence-Alpes-Côte d'Azur
# 47173  2021-03-16      region      REG-94                       Corse
#
#        cas_confirmes  cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  \
# 0                NaN        NaN                  NaN                  NaN
# 1          2727321.0        NaN             149671.0                  NaN
# 2                NaN        NaN                  NaN                  NaN
# 3          2894347.0        NaN             159791.0                  NaN
# 4          2910989.0        NaN             159791.0                  NaN
# ...              ...        ...                  ...                  ...
# 47169            NaN        NaN                  NaN                  NaN
# 47170            NaN        NaN                  NaN                  NaN
# 47171            NaN        NaN                  NaN                  NaN
# 47172            NaN        NaN                  NaN                  NaN
# 47173            NaN        NaN                  NaN                  NaN
#
#          deces  deces_ehpad  reanimation  hospitalises  \
# 0      44985.0      19780.0          NaN       24296.0
# 1      46539.0      20302.0       2582.0       24521.0
# 2      46815.0          NaN          NaN           NaN
# 3      48783.0      21359.0       2741.0       25019.0
# 4      48924.0      21359.0       2776.0       25269.0
# ...        ...          ...          ...           ...
# 47169   3007.0          NaN        193.0        1157.0
# 47170   3415.0          NaN        273.0        1360.0
# 47171   9525.0          NaN        450.0        3118.0
# 47172   6262.0          NaN        511.0        3134.0
# 47173    156.0          NaN         15.0         111.0
#
#        nouvelles_hospitalisations  nouvelles_reanimations    gueris  depistes  \
# 0                             NaN                     NaN  194901.0       NaN
# 1                          1438.0                   180.0  200079.0       NaN
# 2                             NaN                     NaN       NaN       NaN
# 3                          1197.0                   188.0  209056.0       NaN
# 4                           697.0                   136.0  209343.0       NaN
# ...                           ...                     ...       ...       ...
# 47169                        89.0                    15.0   12174.0       NaN
# 47170                        89.0                    17.0   15272.0       NaN
# 47171                       193.0                    46.0   39045.0       NaN
# 47172                       264.0                    41.0   29429.0       NaN
# 47173                         4.0                     2.0     664.0       NaN
#
#                                      source_nom source_url source_archive  \
# 0      Ministère des Solidarités et de la Santé        NaN            NaN
# 1      Ministère des Solidarités et de la Santé        NaN            NaN
# 2      Ministère des Solidarités et de la Santé        NaN            NaN
# 3      Ministère des Solidarités et de la Santé        NaN            NaN
# 4      Ministère des Solidarités et de la Santé        NaN            NaN
# ...                                         ...        ...            ...
# 47169                            OpenCOVID19-fr        NaN            NaN
# 47170                            OpenCOVID19-fr        NaN            NaN
# 47171                            OpenCOVID19-fr        NaN            NaN
# 47172                            OpenCOVID19-fr        NaN            NaN
# 47173                            OpenCOVID19-fr        NaN            NaN
#
#            source_type
# 0      ministere-sante
# 1      ministere-sante
# 2      ministere-sante
# 3      ministere-sante
# 4      ministere-sante
# ...                ...
# 47169   opencovid19-fr
# 47170   opencovid19-fr
# 47171   opencovid19-fr
# 47172   opencovid19-fr
# 47173   opencovid19-fr
#
# [47174 rows x 20 columns]

# %%
#exctraction de colonnes du dataframe df_covid
df2_covid = df_covid.loc[:,['date', 'granularite','maille_code','maille_nom','cas_confirmes','hospitalises']]
#filtrage des données selon le departement
df2_covid = df2_covid.loc[df2_covid['granularite']=="departement",:]

# %%
df2_covid.head(50)
# Out:
#            date  granularite maille_code             maille_nom  \
# 5    2020-01-24  departement      DEP-16               Charente
# 6    2020-01-24  departement      DEP-17      Charente-Maritime
# 7    2020-01-24  departement      DEP-19                Corrèze
# 8    2020-01-24  departement      DEP-23                 Creuse
# 9    2020-01-24  departement      DEP-24               Dordogne
# 10   2020-01-24  departement      DEP-33                Gironde
# 11   2020-01-24  departement      DEP-33                Gironde
# 12   2020-01-24  departement      DEP-40                 Landes
# 13   2020-01-24  departement      DEP-47         Lot-et-Garonne
# 14   2020-01-24  departement      DEP-64   Pyrénées-Atlantiques
# 15   2020-01-24  departement      DEP-79            Deux-Sèvres
# 16   2020-01-24  departement      DEP-86                 Vienne
# 17   2020-01-24  departement      DEP-87           Haute-Vienne
# 26   2020-01-25  departement      DEP-33                Gironde
# 31   2020-01-26  departement      DEP-33                Gironde
# 36   2020-01-27  departement      DEP-33                Gironde
# 37   2020-01-27  departement      DEP-34                Hérault
# 44   2020-01-28  departement      DEP-33                Gironde
# 50   2020-01-29  departement      DEP-33                Gironde
# 57   2020-01-30  departement      DEP-33                Gironde
# 64   2020-01-31  departement      DEP-33                Gironde
# 73   2020-02-03  departement      DEP-33                Gironde
# 82   2020-02-05  departement      DEP-33                Gironde
# 89   2020-02-06  departement      DEP-33                Gironde
# 94   2020-02-07  departement      DEP-33                Gironde
# 95   2020-02-07  departement      DEP-74           Haute-Savoie
# 103  2020-02-08  departement      DEP-33                Gironde
# 104  2020-02-08  departement      DEP-74           Haute-Savoie
# 105  2020-02-08  departement      DEP-74           Haute-Savoie
# 106  2020-02-08  departement      DEP-74           Haute-Savoie
# 116  2020-02-10  departement      DEP-33                Gironde
# 117  2020-02-10  departement      DEP-74           Haute-Savoie
# 125  2020-02-11  departement      DEP-33                Gironde
# 126  2020-02-11  departement      DEP-74           Haute-Savoie
# 132  2020-02-12  departement      DEP-33                Gironde
# 133  2020-02-12  departement      DEP-74           Haute-Savoie
# 148  2020-02-20  departement      DEP-33                Gironde
# 149  2020-02-20  departement      DEP-74           Haute-Savoie
# 158  2020-02-24  departement      DEP-33                Gironde
# 161  2020-02-25  departement      DEP-74           Haute-Savoie
# 167  2020-02-26  departement      DEP-02                  Aisne
# 168  2020-02-26  departement      DEP-25                  Doubs
# 169  2020-02-26  departement      DEP-59                   Nord
# 170  2020-02-26  departement      DEP-60                   Oise
# 171  2020-02-26  departement      DEP-60                   Oise
# 172  2020-02-26  departement      DEP-62          Pas-de-Calais
# 173  2020-02-26  departement      DEP-80                  Somme
# 174  2020-02-26  departement      DEP-90  Territoire de Belfort
# 181  2020-02-27  departement      DEP-21              Côte-d'Or
# 182  2020-02-27  departement      DEP-29              Finistère
#
#      cas_confirmes  hospitalises
# 5              0.0           NaN
# 6              0.0           NaN
# 7              0.0           NaN
# 8              0.0           NaN
# 9              0.0           NaN
# 10             1.0           NaN
# 11             1.0           1.0
# 12             0.0           NaN
# 13             0.0           NaN
# 14             0.0           NaN
# 15             0.0           NaN
# 16             0.0           NaN
# 17             0.0           NaN
# 26             1.0           1.0
# 31             1.0           1.0
# 36             1.0           1.0
# 37             1.0           NaN
# 44             1.0           1.0
# 50             1.0           1.0
# 57             1.0           1.0
# 64             1.0           1.0
# 73             1.0           1.0
# 82             1.0           1.0
# 89             1.0           1.0
# 94             1.0           1.0
# 95             5.0           NaN
# 103            1.0           1.0
# 104            5.0           NaN
# 105            5.0           5.0
# 106            6.0           NaN
# 116            1.0           1.0
# 117            5.0           NaN
# 125            1.0           1.0
# 126            5.0           NaN
# 132            1.0           1.0
# 133            5.0           NaN
# 148            1.0           1.0
# 149            6.0           NaN
# 158            1.0           NaN
# 161            7.0           NaN
# 167            0.0           NaN
# 168            1.0           NaN
# 169            0.0           NaN
# 170            2.0           NaN
# 171            2.0           NaN
# 172            0.0           NaN
# 173            0.0           NaN
# 174            2.0           NaN
# 181            1.0           NaN
# 182            1.0           NaN

# %%
df2_covid["date"] = pd.to_datetime(df2_covid.date)

# %%
df2_covid.dtypes
# Out:
# date             datetime64[ns]
# granularite              object
# maille_code              object
# maille_nom               object
# cas_confirmes           float64
# hospitalises            float64
# dtype: object

# %%
index_with_nan = df2_covid.index[df2_covid.isnull().any(axis=1)]

print(index_with_nan)

df2_covid.drop(index_with_nan,0, inplace=True)

df2_covid.tail(100)
# Out:
# Int64Index([    5,     6,     7,     8,     9,    10,    12,    13,    14,
#                15,
#             ...
#             47145, 47146, 47147, 47148, 47149, 47150, 47151, 47152, 47153,
#             47154],
#            dtype='int64', length=38696)
#            date  granularite maille_code maille_nom  cas_confirmes  \
# 11   2020-01-24  departement      DEP-33    Gironde            1.0
# 26   2020-01-25  departement      DEP-33    Gironde            1.0
# 31   2020-01-26  departement      DEP-33    Gironde            1.0
# 36   2020-01-27  departement      DEP-33    Gironde            1.0
# 44   2020-01-28  departement      DEP-33    Gironde            1.0
# ...         ...          ...         ...        ...            ...
# 4639 2020-03-30  departement     DEP-976    Mayotte           82.0
# 4785 2020-03-31  departement     DEP-976    Mayotte           94.0
# 4916 2020-04-01  departement     DEP-976    Mayotte          101.0
# 5041 2020-04-02  departement     DEP-976    Mayotte          116.0
# 5165 2020-04-03  departement     DEP-976    Mayotte          128.0
#
#       hospitalises
# 11             1.0
# 26             1.0
# 31             1.0
# 36             1.0
# 44             1.0
# ...            ...
# 4639          10.0
# 4785          10.0
# 4916          11.0
# 5041          13.0
# 5165          14.0
#
# [100 rows x 6 columns]

# %%
import geopandas as gpd
sf = gpd.read_file('departements.geojson')
sf.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-38-764dcb2bad68> in <module>()
# ----> 1 import geopandas as gpd
#       2 sf = gpd.read_file('departements.geojson')
#       3 sf.head()
#
# ~\Anaconda3\lib\site-packages\geopandas\__init__.py in <module>()
# ----> 1 from geopandas._config import options  # noqa
#       2
#       3 from geopandas.geoseries import GeoSeries  # noqa
#       4 from geopandas.geodataframe import GeoDataFrame  # noqa
#       5 from geopandas.array import points_from_xy  # noqa
#
# ~\Anaconda3\lib\site-packages\geopandas\_config.py in <module>()
#     124 use_pygeos = Option(
#     125     key="use_pygeos",
# --> 126     default_value=_default_use_pygeos(),
#     127     doc=(
#     128         "Whether to use PyGEOS to speed up spatial operations. The default is True "
#
# ~\Anaconda3\lib\site-packages\geopandas\_config.py in _default_use_pygeos()
#     110
#     111 def _default_use_pygeos():
# --> 112     import geopandas._compat as compat
#     113
#     114     return compat.USE_PYGEOS
#
# ~\Anaconda3\lib\site-packages\geopandas\_compat.py in <module>()
#       8 import pyproj
#       9 import shapely
# ---> 10 import shapely.geos
#      11
#      12
#
# ~\Anaconda3\lib\site-packages\shapely\geos.py in <module>()
#     152     if os.getenv('CONDA_PREFIX', ''):
#     153         # conda package.
# --> 154         _lgeos = CDLL(os.path.join(sys.prefix, 'Library', 'bin', 'geos_c.dll'))
#     155     else:
#     156         try:
#
# ~\Anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: [WinError 126] Le module spécifié est introuvable

# %%
jf = sf.merge(df2_covid, left_on='code', right_on='depcode', suffixes=('','_y'))
jf.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-131b23b8a131> in <module>()
# ----> 1 jf = sf.merge(df2_covid, left_on='code', right_on='depcode', suffixes=('','_y'))
#       2 jf.head(2)
#
# NameError: name 'sf' is not defined
