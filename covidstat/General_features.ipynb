# %% [markdown]
# **Descriptive Diagrams**

# %% [markdown]
# import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact  # widget manipulation
from download import download
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import ipywidgets as widgets
import data

# %%
from data.viz import *

# %% [markdown]
# Import Data

# %%
file_name = 'data/santé_publique_France_data-chiffres-cles.csv'
url = 'https://raw.githubusercontent.com/opencovid19-fr/data/master/dist/chiffres-cles.csv'
myfile = requests.get(url)
open(file_name, 'wb').write(myfile.content)
data = pd.read_csv('data/santé_publique_France_data-chiffres-cles.csv')
# Out:
# C:\Users\Jihene Belgaied\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data = enable_time_series_plot(data, timein_field="date", timeseries_field_out="t")
# Out:
# c:\ProjetCovid\covidestat\viz.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_df[timeseries_field_out] = pd.to_datetime(

# %%
data = data.loc[data['granularite']=="departement",:]
# Out:
#              date  granularite maille_code         maille_nom  cas_confirmes  \
# 5      2020-01-24  departement      DEP-16           Charente            0.0
# 6      2020-01-24  departement      DEP-17  Charente-Maritime            0.0
# 7      2020-01-24  departement      DEP-19            Corrèze            0.0
# 8      2020-01-24  departement      DEP-23             Creuse            0.0
# 9      2020-01-24  departement      DEP-24           Dordogne            0.0
# ...           ...          ...         ...                ...            ...
# 50990  2021-04-17  departement     DEP-971         Guadeloupe            NaN
# 50991  2021-04-17  departement     DEP-972         Martinique            NaN
# 50992  2021-04-17  departement     DEP-973             Guyane            NaN
# 50993  2021-04-17  departement     DEP-974         La Réunion            NaN
# 50994  2021-04-17  departement     DEP-976            Mayotte            NaN
#
#        cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  deces  \
# 5            NaN                  NaN                  NaN    NaN
# 6            NaN                  NaN                  NaN    NaN
# 7            NaN                  NaN                  NaN    NaN
# 8            NaN                  NaN                  NaN    NaN
# 9            NaN                  NaN                  NaN    NaN
# ...          ...                  ...                  ...    ...
# 50990        NaN                  NaN                  NaN  219.0
# 50991        NaN                  NaN                  NaN   67.0
# 50992        NaN                  NaN                  NaN   92.0
# 50993        NaN                  NaN                  NaN  148.0
# 50994        NaN                  NaN                  NaN  124.0
#
#        deces_ehpad  ...  hospitalises  nouvelles_hospitalisations  \
# 5              NaN  ...           NaN                         NaN
# 6              NaN  ...           NaN                         NaN
# 7              NaN  ...           NaN                         NaN
# 8              NaN  ...           NaN                         NaN
# 9              NaN  ...           NaN                         NaN
# ...            ...  ...           ...                         ...
# 50990          NaN  ...         115.0                        12.0
# 50991          NaN  ...         105.0                         7.0
# 50992          NaN  ...          39.0                         2.0
# 50993          NaN  ...         140.0                        10.0
# 50994          NaN  ...          14.0                         2.0
#
#        nouvelles_reanimations  gueris  depistes                  source_nom  \
# 5                         NaN     NaN       NaN      ARS Nouvelle-Aquitaine
# 6                         NaN     NaN       NaN      ARS Nouvelle-Aquitaine
# 7                         NaN     NaN       NaN      ARS Nouvelle-Aquitaine
# 8                         NaN     NaN       NaN      ARS Nouvelle-Aquitaine
# 9                         NaN     NaN       NaN      ARS Nouvelle-Aquitaine
# ...                       ...     ...       ...                         ...
# 50990                     3.0   991.0       NaN  Santé publique France Data
# 50991                     1.0   567.0       NaN  Santé publique France Data
# 50992                     0.0  2305.0       NaN  Santé publique France Data
# 50993                     4.0  1336.0       NaN  Santé publique France Data
# 50994                     0.0  1228.0       NaN  Santé publique France Data
#
#                                               source_url source_archive  \
# 5      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 6      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 7      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 8      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 9      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# ...                                                  ...            ...
# 50990                                                NaN            NaN
# 50991                                                NaN            NaN
# 50992                                                NaN            NaN
# 50993                                                NaN            NaN
# 50994                                                NaN            NaN
#
#                       source_type          t
# 5        agences-regionales-sante 2020-01-24
# 6        agences-regionales-sante 2020-01-24
# 7        agences-regionales-sante 2020-01-24
# 8        agences-regionales-sante 2020-01-24
# 9        agences-regionales-sante 2020-01-24
# ...                           ...        ...
# 50990  sante-publique-france-data 2021-04-17
# 50991  sante-publique-france-data 2021-04-17
# 50992  sante-publique-france-data 2021-04-17
# 50993  sante-publique-france-data 2021-04-17
# 50994  sante-publique-france-data 2021-04-17
#
# [42028 rows x 21 columns]

# %%
data=data.loc[data["source_nom"] == "Santé publique France Data",:]
# Out:
#              date  granularite maille_code               maille_nom  \
# 1996   2020-03-18  departement      DEP-01                      Ain
# 1998   2020-03-18  departement      DEP-02                    Aisne
# 2000   2020-03-18  departement      DEP-03                   Allier
# 2002   2020-03-18  departement      DEP-04  Alpes-de-Haute-Provence
# 2004   2020-03-18  departement      DEP-05             Hautes-Alpes
# ...           ...          ...         ...                      ...
# 50990  2021-04-17  departement     DEP-971               Guadeloupe
# 50991  2021-04-17  departement     DEP-972               Martinique
# 50992  2021-04-17  departement     DEP-973                   Guyane
# 50993  2021-04-17  departement     DEP-974               La Réunion
# 50994  2021-04-17  departement     DEP-976                  Mayotte
#
#        cas_confirmes  cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  \
# 1996             NaN        NaN                  NaN                  NaN
# 1998             NaN        NaN                  NaN                  NaN
# 2000             NaN        NaN                  NaN                  NaN
# 2002             NaN        NaN                  NaN                  NaN
# 2004             NaN        NaN                  NaN                  NaN
# ...              ...        ...                  ...                  ...
# 50990            NaN        NaN                  NaN                  NaN
# 50991            NaN        NaN                  NaN                  NaN
# 50992            NaN        NaN                  NaN                  NaN
# 50993            NaN        NaN                  NaN                  NaN
# 50994            NaN        NaN                  NaN                  NaN
#
#        deces  deces_ehpad  ...  hospitalises  nouvelles_hospitalisations  \
# 1996     0.0          NaN  ...           2.0                         NaN
# 1998    11.0          NaN  ...          41.0                         NaN
# 2000     0.0          NaN  ...           4.0                         NaN
# 2002     0.0          NaN  ...           3.0                         NaN
# 2004     0.0          NaN  ...           8.0                         NaN
# ...      ...          ...  ...           ...                         ...
# 50990  219.0          NaN  ...         115.0                        12.0
# 50991   67.0          NaN  ...         105.0                         7.0
# 50992   92.0          NaN  ...          39.0                         2.0
# 50993  148.0          NaN  ...         140.0                        10.0
# 50994  124.0          NaN  ...          14.0                         2.0
#
#        nouvelles_reanimations  gueris  depistes                  source_nom  \
# 1996                      NaN     1.0       NaN  Santé publique France Data
# 1998                      NaN    18.0       NaN  Santé publique France Data
# 2000                      NaN     1.0       NaN  Santé publique France Data
# 2002                      NaN     2.0       NaN  Santé publique France Data
# 2004                      NaN     9.0       NaN  Santé publique France Data
# ...                       ...     ...       ...                         ...
# 50990                     3.0   991.0       NaN  Santé publique France Data
# 50991                     1.0   567.0       NaN  Santé publique France Data
# 50992                     0.0  2305.0       NaN  Santé publique France Data
# 50993                     4.0  1336.0       NaN  Santé publique France Data
# 50994                     0.0  1228.0       NaN  Santé publique France Data
#
#       source_url source_archive                 source_type          t
# 1996         NaN            NaN  sante-publique-france-data 2020-03-18
# 1998         NaN            NaN  sante-publique-france-data 2020-03-18
# 2000         NaN            NaN  sante-publique-france-data 2020-03-18
# 2002         NaN            NaN  sante-publique-france-data 2020-03-18
# 2004         NaN            NaN  sante-publique-france-data 2020-03-18
# ...          ...            ...                         ...        ...
# 50990        NaN            NaN  sante-publique-france-data 2021-04-17
# 50991        NaN            NaN  sante-publique-france-data 2021-04-17
# 50992        NaN            NaN  sante-publique-france-data 2021-04-17
# 50993        NaN            NaN  sante-publique-france-data 2021-04-17
# 50994        NaN            NaN  sante-publique-france-data 2021-04-17
#
# [39996 rows x 21 columns]

# %%
data['date'] = pd.to_datetime(data['date'])
# Out:
# <ipython-input-7-a011fda2e204>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])

# %% [markdown]
# Set the current date for the chart :

# %%
current_date = data['date'].max().strftime('%d/%m/%Y')

# %% [markdown]
# Create different datasets useful for the charts :

# %%
gb_data= data[data['date'] == data['date'].max()].reset_index()
current_date = gb_data['date'].max().strftime('%d/%m/%Y')
#hospitalisees total = hospitalises + gueris
data_ratio_hospitalises = (gb_data['deces'] / (gb_data['hospitalises'] + gb_data['gueris'])) * 100
data_hospitalises = gb_data['hospitalises'] + gb_data['gueris']
data_deces = gb_data['deces']
data_depcode = gb_data['maille_nom']

# %% [markdown]
# **Ratio des descès par rapport au nombre d'hospitalisations à la date updated :**

# %%
import matplotlib.ticker as mtick

fig, ax = plt.subplots(figsize=(12, 8))

plt.title(f"Ratio des décès à l'hôpital par rapport au nombre d'hospitalisations au {current_date}", fontsize=20)
plt.ylabel("Nombre cumulé de décès / Nombre cumulé d'hospitalisations")
plt.xlabel("Nombre cumulé de patients hospitalisés")

nbhospitalises_80p = data_hospitalises.sum() * 0.80
min_value_80p = data_hospitalises.loc[data_hospitalises[data_hospitalises.sort_values(ascending=False).cumsum() <= nbhospitalises_80p].index].min()

for i, txt in enumerate(data_depcode):
    if (data_hospitalises[i] > data_hospitalises.max() * 0.20):
    #if (data_hospitalises[i] > min_value_80p):
        ax.annotate(txt, (data_hospitalises[i], data_ratio_hospitalises[i]), xytext=(data_hospitalises[i] + 20, data_ratio_hospitalises[i]))        

plt.axhline(data_ratio_hospitalises.mean(), color='green', linestyle='--', label=f'Ratio de décès moyen ({data_ratio_hospitalises.mean():.2f}%)')

plt.axvline(min_value_80p, color='pink', linestyle='-', label=f"80% du nb d'hospitalisés en France sont à droite de la ligne ({nbhospitalises_80p:.0f} hospitalisés)")

ax.scatter(data_hospitalises, data_ratio_hospitalises)

ax.annotate('Graphique actualisé',xy=(1, 0), xytext=(-15, 10), fontsize=15,
    xycoords='axes fraction', textcoords='offset points',
    bbox=dict(facecolor='white', alpha=0.9),
    horizontalalignment='right', verticalalignment='bottom')

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.0f%%'))
plt.legend()

current_date_file = gb_data['date'].max().strftime('%Y%m%d')
plt.savefig('covid19-comparatif-departements-'+str(current_date_file)+'.png')

# %% [markdown]
# **Nombre de décès à l'hôpital par rapport au nombre d'hospitalisations à la date updated**

# %%
import seaborn as sns; sns.set(color_codes=True)

plt.figure(figsize=(12, 8))

plt.title(f"Nombre de décès à l'hôpital par rapport au nombre d'hospitalisations au {current_date}", fontsize=25)
# Set x-axis label

ax = sns.regplot(x=data_hospitalises, y=data_deces, ci=99.9, truncate=False)

ax.set(xlabel="Nombre cumulé d'hospitalisés depuis le début de la crise", ylabel='Nombre de décès')
plt.axvline(min_value_80p, color='pink', linestyle='-', label=f"80% du nb d'hospitalisés en France sont à droite de la ligne ({nbhospitalises_80p:.0f} hospitalisés)")
plt.legend()

for i, txt in enumerate(data_depcode):
    if (data_hospitalises[i] > data_hospitalises.max() * 0.20):
        ax.annotate(txt, (data_hospitalises[i], data_deces[i]), xytext=(data_hospitalises[i] + 20, data_deces[i]))      
        #ax.annotate(txt, (data_hospitalises[i], data_hospitalises[i]))      
        
ax.annotate('Visu', xy=(1, 0), xytext=(-5, 5), fontsize=6,
    xycoords='axes fraction', textcoords='offset points',
    bbox=dict(facecolor='white', alpha=0.8),
    horizontalalignment='right', verticalalignment='bottom')
        
#plt.savefig('covid19-comparatif-departements-regplot-'+str(current_date_file)+'.png')
# Out:
# Text(-5, 5, 'Visu')
